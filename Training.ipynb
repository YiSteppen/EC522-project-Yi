# %% [markdown]
# # **Training**: Physics-based Learned Design
#
#
# **Purpose:** Train a physics-based network to learn the experiment design (LED patterns) for Fourier Ptychographic Microscopy.
#
# **Monitor Training:** If you have enabled tensorboards (```tensorboard=True```), start the tensorboard (```tensorboard --logdir runs```) and the training can be monitored during training at the specified link.
#
# **Parameters:**
# * path (string) - _training dataset path_
# * training_iter (int) - _number of iterations for training_
# * step_size (float) - _step size for training_
# * batch_size (int) - _batch size per training iteration_
# * num_batch (int) - _number of batches_
# * loss (string) - _loss function for training (mse on the complex value, mse on the amplitude, mse on the phase)_
# * test_freq (int) - _test dataset evaluated every number of training iterations_
# * optim (string) - _optimizer for training (_e.g._ adam, sgd)_
# * gpu (int) - _GPU device number used for training (-1 for cpu)_
# * verbose (bool) - _prints extra outputs_
# * tensorboard (bool) - _writes out intermediate training information to a tensorboard_
# * alpha (float) - _step size for physics-based network_
# * num_meas (int) - _number of measurements for the learned design_
# * num_bf (int) - _number of bright-field images for learned design constraint_
# * num_df (int) - _number of dark-field images for learned design constraint_
# * num_unrolls (int) - _number of layers for physics-based network_
#
# **Author:** Michael Kellman (kellman dot berkeley dot edu)

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

import os
import sys
import time
import numpy as np
import torch
from torch.utils.tensorboard import SummaryWriter
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from datetime import datetime
import time

sys.path.append('./source/')
import dataloader
import visualizer
import model
from recon import evaluate, makeNetwork
from utility import getPhase, getAbs

def get_time_stamp():
    return str(datetime.now())[11:19] + '_'

def format_loss_monitor(batch, loss, time):
    return 'batch={0:3d} | loss={1:.5f} | log loss={2:2.3f} | time={3:2.3f}'.format(batch, loss, np.log10(loss), time)

# %%
# learning arguments
num_batches = 10
batch_size = 1
path = './data/test/' ### RUN GENERATE DATA AND PUT YOUR PATH HERE
training_iter = 100
step_size = 0.01
loss = 'abs' # other options include mse on only the abs or the phase)
test_freq = 1
optim = 'adam' # other options include sgd
gpu = 0 # if -1 then 'cpu'
verbose = False
tensorboard = False

# reconstruction arguments
alpha = 1e-1
num_meas = 8
num_bf = 2
num_df = 6
num_unrolls = 75

# %%
# Setup device
if gpu < 0:
    device = 'gpu'
else:
    torch.cuda.set_device(gpu)
    device = torch.device("cuda:"+str(gpu) if torch.cuda.is_available() else "cpu")

# %%
# Load dataset
dataset = dataloader.dataloader(path, batch_size, loadBatchFlag=True, device=device)
metadata = dataset.getMetadata()
print(metadata)
metadata['Np'] = dataset[0][0].shape[1:]
print(metadata['Np'])
metadata['num_bf'] = num_bf
metadata['num_df'] = num_df
metadata['num_unrolls'] = num_unrolls
metadata['alpha'] = alpha
# Out:
# ['batch00.mat', 'batch01.mat', 'batch02.mat', 'batch03.mat', 'experimental_phase_USAF_data.mat', 'metadata.mat', 'training_data_phase.mat']
# b
# batch00.mat
# b
# batch01.mat
# b
# batch02.mat
# b
# batch03.mat
# e
# m
# t
# {'ps': 6.5, 'wl': 0.514, 'mag': 4, 'na': 0.2, 'na_illum': 0.42000000000000004, 'Nleds': 89, 'z_offset': 0, 'na_list': array([[-1.76630435e-05, -1.76630435e-05],
#        [ 8.66121517e-02, -1.75966676e-05],
#        [-1.75966676e-05,  8.66121517e-02],
#        [-1.75966140e-05, -8.66470809e-02],
#        [-8.66470809e-02, -1.75966140e-05],
#        [ 8.62891005e-02,  8.62891005e-02],
#        [ 8.62888394e-02, -8.63239014e-02],
#        [-8.63239014e-02,  8.62888394e-02],
#        [-8.63236401e-02, -8.63236401e-02],
#        [ 1.71324284e-01, -1.74018899e-05],
#        [-1.74018899e-05,  1.71324284e-01],
#        [-1.74017862e-05, -1.71358066e-01],
#        [-1.71358066e-01, -1.74017862e-05],
#        [ 1.70699259e-01,  8.53409605e-02],
#        [ 8.53409605e-02,  1.70699259e-01],
#        [ 1.70698754e-01, -8.53753846e-02],
#        [-8.53753846e-02,  1.70698754e-01],
#        [ 8.53404553e-02, -1.70732926e-01],
#        [-1.70732926e-01,  8.53404553e-02],
#        [-8.53748792e-02, -1.70732420e-01],
#        [-1.70732420e-01, -8.53748792e-02],
#        [ 1.68863959e-01,  1.68863959e-01],
#        [ 1.68862980e-01, -1.68897284e-01],
#        [-1.68897284e-01,  1.68862980e-01],
#        [-1.68896306e-01, -1.68896306e-01],
#        [ 2.52405895e-01, -1.70911397e-05],
#        [-1.70911397e-05,  2.52405895e-01],
#        [-1.70909922e-05, -2.52437899e-01],
#        [-2.52437899e-01, -1.70909922e-05],
#        [ 2.51517491e-01,  8.38278095e-02],
#        [ 8.38278095e-02,  2.51517491e-01],
#        [ 2.51516772e-01, -8.38616320e-02],
#        [-8.38616320e-02,  2.51516772e-01],
#        [ 8.38270913e-02, -2.51549397e-01],
#        [-2.51549397e-01,  8.38270913e-02],
#        [-8.38609135e-02, -2.51548679e-01],
#        [-2.51548679e-01, -8.38609135e-02],
#        [ 2.48906830e-01,  1.65932269e-01],
#        [ 1.65932269e-01,  2.48906830e-01],
#        [ 2.48905438e-01, -1.65965049e-01],
#        [-1.65965049e-01,  2.48905438e-01],
#        [ 1.65930877e-01, -2.48938450e-01],
#        [-2.48938450e-01,  1.65930877e-01],
#        [-1.65963656e-01, -2.48937057e-01],
#        [-2.48937057e-01, -1.65963656e-01],
#        [ 3.28505743e-01, -1.66827794e-05],
#        [-1.66827794e-05,  3.28505743e-01],
#        [-1.66825966e-05, -3.28535507e-01],
#        [-3.28535507e-01, -1.66825966e-05],
#        [ 3.27403805e-01,  8.18384811e-02],
#        [ 8.18384811e-02,  3.27403805e-01],
#        [ 3.27402914e-01, -8.18715119e-02],
#        [-8.18715119e-02,  3.27402914e-01],
#        [ 8.18375900e-02, -3.27433493e-01],
#        [-3.27433493e-01,  8.18375900e-02],
#        [-8.18706205e-02, -3.27432602e-01],
#        [-3.27432602e-01, -8.18706205e-02],
#        [ 2.44730519e-01,  2.44730519e-01],
#        [ 2.44728534e-01, -2.44761676e-01],
#        [-2.44761676e-01,  2.44728534e-01],
#        [-2.44759691e-01, -2.44759691e-01],
#        [ 3.24162492e-01,  1.62073015e-01],
#        [ 1.62073015e-01,  3.24162492e-01],
#        [ 3.24160762e-01, -1.62105074e-01],
#        [-1.62105074e-01,  3.24160762e-01],
#        [ 1.62071285e-01, -3.24191956e-01],
#        [-3.24191956e-01,  1.62071285e-01],
#        [-1.62103344e-01, -3.24190226e-01],
#        [-3.24190226e-01, -1.62103344e-01],
#        [ 3.18967575e-01,  2.39221632e-01],
#        [ 2.39221632e-01,  3.18967575e-01],
#        [ 3.98712488e-01, -1.61983529e-05],
#        [-1.61983529e-05,  3.98712488e-01],
#        [ 3.18965103e-01, -2.39252174e-01],
#        [-2.39252174e-01,  3.18965103e-01],
#        [ 2.39219160e-01, -3.18996675e-01],
#        [-3.18996675e-01,  2.39219160e-01],
#        [-1.61981437e-05, -3.98739734e-01],
#        [-3.98739734e-01, -1.61981437e-05],
#        [-2.39249702e-01, -3.18994203e-01],
#        [-3.18994203e-01, -2.39249702e-01],
#        [ 3.97451231e-01,  7.94773284e-02],
#        [ 7.94773284e-02,  3.97451231e-01],
#        [ 3.97450210e-01, -7.95094185e-02],
#        [-7.95094185e-02,  3.97450210e-01],
#        [ 7.94763083e-02, -3.97478423e-01],
#        [-3.97478423e-01,  7.94763083e-02],
#        [-7.95083980e-02, -3.97477403e-01],
#        [-3.97477403e-01, -7.95083980e-02],
#        [ 3.93737091e-01,  1.57485239e-01],
#        [ 1.57485239e-01,  3.93737091e-01],
#        [ 3.93735107e-01, -1.57516437e-01],
#        [-1.57516437e-01,  3.93735107e-01],
#        [ 1.57483255e-01, -3.93764123e-01],
#        [-3.93764123e-01,  1.57483255e-01],
#        [-1.57514453e-01, -3.93762139e-01],
#        [-3.93762139e-01, -1.57514453e-01],
#        [ 3.12096964e-01,  3.12096964e-01],
#        [ 3.12093876e-01, -3.12125575e-01],
#        [-3.12125575e-01,  3.12093876e-01],
#        [-3.12122487e-01, -3.12122487e-01],
#        [ 3.87771404e-01,  2.32656541e-01],
#        [ 2.32656541e-01,  3.87771404e-01],
#        [ 3.87768561e-01, -2.32686343e-01],
#        [-2.32686343e-01,  3.87768561e-01],
#        [ 2.32653698e-01, -3.87798173e-01],
#        [-3.87798173e-01,  2.32653698e-01],
#        [-2.32683500e-01, -3.87795330e-01],
#        [-3.87795330e-01, -2.32683500e-01],
#        [ 4.62553697e-01, -1.56599001e-05],
#        [-1.56599001e-05,  4.62553697e-01],
#        [-1.56596732e-05, -4.62578316e-01],
#        [-4.62578316e-01, -1.56596732e-05],
#        [ 4.61185726e-01,  7.68512764e-02],
#        [ 7.68512764e-02,  4.61185726e-01],
#        [ 4.61184619e-01, -7.68823190e-02],
#        [-7.68823190e-02,  4.61184619e-01],
#        [ 7.68501696e-02, -4.61210311e-01],
#        [-4.61210311e-01,  7.68501696e-02],
#        [-7.68812118e-02, -4.61209204e-01],
#        [-4.61209204e-01, -7.68812118e-02],
#        [ 4.57152426e-01,  1.52373824e-01],
#        [ 1.52373824e-01,  4.57152426e-01],
#        [ 4.57150270e-01, -1.52404059e-01],
#        [-1.52404059e-01,  4.57150270e-01],
#        [ 1.52371668e-01, -4.57176911e-01],
#        [-4.57176911e-01,  1.52371668e-01],
#        [-1.52401903e-01, -4.57174754e-01],
#        [-4.57174754e-01, -1.52401903e-01],
#        [ 3.79857164e-01,  3.03882645e-01],
#        [ 3.03882645e-01,  3.79857164e-01],
#        [ 3.79853601e-01, -3.03910659e-01],
#        [-3.03910659e-01,  3.79853601e-01],
#        [ 3.03879082e-01, -3.79883575e-01],
#        [-3.79883575e-01,  3.03879082e-01],
#        [-3.03907096e-01, -3.79880012e-01],
#        [-3.79880012e-01, -3.03907096e-01],
#        [ 4.50658851e-01,  2.25321797e-01],
#        [ 2.25321797e-01,  4.50658851e-01],
#        [ 4.50655752e-01, -2.25350762e-01],
#        [-2.25350762e-01,  4.50655752e-01],
#        [ 2.25318698e-01, -4.50683167e-01],
#        [-4.50683167e-01,  2.25318698e-01],
#        [-2.25347663e-01, -4.50680068e-01],
#        [-4.50680068e-01, -2.25347663e-01],
#        [ 5.19935938e-01, -1.50878646e-05],
#        [-1.50878646e-05,  5.19935938e-01],
#        [-1.50876279e-05, -5.19957956e-01],
#        [-5.19957956e-01, -1.50876279e-05],
#        [ 3.70359452e-01,  3.70359452e-01],
#        [ 5.18508095e-01,  7.40596881e-02],
#        [ 7.40596881e-02,  5.18508095e-01],
#        [ 5.18506939e-01, -7.40896158e-02],
#        [-7.40896158e-02,  5.18506939e-01],
#        [ 3.70355324e-01, -3.70385417e-01],
#        [-3.70385417e-01,  3.70355324e-01],
#        [ 7.40585325e-02, -5.18530097e-01],
#        [-5.18530097e-01,  7.40585325e-02],
#        [-7.40884598e-02, -5.18528941e-01],
#        [-5.18528941e-01, -7.40884598e-02],
#        [-3.70381289e-01, -3.70381289e-01],
#        [ 4.42015590e-01,  2.94672072e-01],
#        [ 2.94672072e-01,  4.42015590e-01],
#        [ 4.42011691e-01, -2.94699402e-01],
#        [-2.94699402e-01,  4.42011691e-01],
#        [ 2.94668173e-01, -4.42039671e-01],
#        [-4.42039671e-01,  2.94668173e-01],
#        [-2.94695503e-01, -4.42035772e-01],
#        [-4.42035772e-01, -2.94695503e-01],
#        [ 5.14293002e-01,  1.46930198e-01],
#        [ 1.46930198e-01,  5.14293002e-01],
#        [ 5.14290746e-01, -1.46959401e-01],
#        [-1.46959401e-01,  5.14290746e-01],
#        [ 1.46927942e-01, -5.14314955e-01],
#        [-5.14314955e-01,  1.46927942e-01],
#        [-1.46957145e-01, -5.14312699e-01],
#        [-5.14312699e-01, -1.46957145e-01],
#        [ 5.07490295e-01,  2.17487426e-01],
#        [ 2.17487426e-01,  5.07490295e-01],
#        [ 5.07487044e-01, -2.17515486e-01],
#        [-2.17515486e-01,  5.07487044e-01],
#        [ 2.17484175e-01, -5.07512163e-01],
#        [-5.07512163e-01,  2.17484175e-01],
#        [-2.17512234e-01, -5.07508911e-01],
#        [-5.07508911e-01, -2.17512234e-01],
#        [ 4.31600379e-01,  3.59664547e-01],
#        [ 3.59664547e-01,  4.31600379e-01],
#        [ 4.31595843e-01, -3.59689990e-01],
#        [-3.59689990e-01,  4.31595843e-01],
#        [ 3.59660011e-01, -4.31624159e-01],
#        [-4.31624159e-01,  3.59660011e-01],
#        [-3.59685454e-01, -4.31619622e-01],
#        [-4.31619622e-01, -3.59685454e-01],
#        [ 5.71054717e-01, -1.44998043e-05],
#        [-1.44998043e-05,  5.71054717e-01],
#        [-1.44995642e-05, -5.71074259e-01],
#        [-5.71074259e-01, -1.44995642e-05],
#        [ 4.98404381e-01,  2.84796305e-01],
#        [ 2.84796305e-01,  4.98404381e-01],
#        [ 5.69605900e-01,  7.11880823e-02],
#        [ 7.11880823e-02,  5.69605900e-01],
#        [ 5.69604727e-01, -7.12168617e-02],
#        [-7.12168617e-02,  5.69604727e-01],
#        [ 4.98400275e-01, -2.84822885e-01],
#        [-2.84822885e-01,  4.98400275e-01],
#        [ 2.84792199e-01, -4.98426121e-01],
#        [-4.98426121e-01,  2.84792199e-01],
#        [ 7.11869094e-02, -5.69625440e-01],
#        [-5.69625440e-01,  7.11869094e-02],
#        [-7.12156883e-02, -5.69624267e-01],
#        [-5.69624267e-01, -7.12156883e-02],
#        [-2.84818778e-01, -4.98422015e-01],
#        [-4.98422015e-01, -2.84818778e-01],
#        [ 5.65323583e-01,  1.41320130e-01],
#        [ 1.41320130e-01,  5.65323583e-01],
#        [ 5.65321289e-01, -1.41348265e-01],
#        [-1.41348265e-01,  5.65321289e-01],
#        [ 1.41317836e-01, -5.65343116e-01],
#        [-5.65343116e-01,  1.41317836e-01],
#        [-1.41345971e-01, -5.65340822e-01],
#        [-5.65340822e-01, -1.41345971e-01],
#        [ 4.19817654e-01,  4.19817654e-01],
#        [ 4.19812644e-01, -4.19841070e-01],
#        [-4.19841070e-01,  4.19812644e-01],
#        [-4.19836060e-01, -4.19836060e-01],
#        [ 5.58395751e-01,  2.09389545e-01],
#        [ 2.09389545e-01,  5.58395751e-01],
#        [ 5.58392435e-01, -2.09416658e-01],
#        [-2.09416658e-01,  5.58392435e-01],
#        [ 2.09386229e-01, -5.58415265e-01],
#        [-5.58415265e-01,  2.09386229e-01],
#        [-2.09413342e-01, -5.58411949e-01],
#        [-5.58411949e-01, -2.09413342e-01],
#        [ 4.87409053e-01,  3.48145283e-01],
#        [ 3.48145283e-01,  4.87409053e-01],
#        [ 4.87404253e-01, -3.48170141e-01],
#        [-3.48170141e-01,  4.87404253e-01],
#        [ 3.48140482e-01, -4.87430620e-01],
#        [-4.87430620e-01,  3.48140482e-01],
#        [-3.48165341e-01, -4.87425820e-01],
#        [-4.87425820e-01, -3.48165341e-01],
#        [ 5.49110942e-01,  2.74548500e-01],
#        [ 2.74548500e-01,  5.49110942e-01],
#        [ 5.49106738e-01, -2.74574283e-01],
#        [-2.74574283e-01,  5.49106738e-01],
#        [ 2.74544296e-01, -5.49130419e-01],
#        [-5.49130419e-01,  2.74544296e-01],
#        [-2.74570078e-01, -5.49126215e-01],
#        [-5.49126215e-01, -2.74570078e-01],
#        [ 6.16299635e-01, -1.39098543e-05],
#        [-1.39098543e-05,  6.16299635e-01],
#        [-1.39096158e-05, -6.16316888e-01],
#        [-6.16316888e-01, -1.39096158e-05],
#        [ 6.14860239e-01,  6.83054689e-02],
#        [ 6.83054689e-02,  6.14860239e-01],
#        [ 6.14859073e-01, -6.83330941e-02],
#        [-6.83330941e-02,  6.14859073e-01],
#        [ 6.83043033e-02, -6.14877501e-01],
#        [-6.14877501e-01,  6.83043033e-02],
#        [-6.83319280e-02, -6.14876335e-01],
#        [-6.14876335e-01, -6.83319280e-02],
#        [ 4.74909463e-01,  4.07063286e-01],
#        [ 4.07063286e-01,  4.74909463e-01],
#        [ 6.10600677e-01,  1.35678321e-01],
#        [ 1.35678321e-01,  6.10600677e-01],
#        [ 6.10598393e-01, -1.35705376e-01],
#        [-1.35705376e-01,  6.10598393e-01],
#        [ 4.74904135e-01, -4.07086281e-01],
#        [-4.07086281e-01,  4.74904135e-01],
#        [ 4.07057957e-01, -4.74930809e-01],
#        [-4.74930809e-01,  4.07057957e-01],
#        [ 1.35676037e-01, -6.10617963e-01],
#        [-6.10617963e-01,  1.35676037e-01],
#        [-1.35703092e-01, -6.10615679e-01],
#        [-6.10615679e-01, -1.35703092e-01],
#        [-4.07080952e-01, -4.74925481e-01],
#        [-4.74925481e-01, -4.07080952e-01],
#        [ 5.37826879e-01,  3.36136679e-01],
#        [ 3.36136679e-01,  5.37826879e-01],
#        [ 5.37821942e-01, -3.36160904e-01],
#        [-3.36160904e-01,  5.37821942e-01],
#        [ 3.36131741e-01, -5.37846291e-01],
#        [-5.37846291e-01,  3.36131741e-01],
#        [-3.36155967e-01, -5.37841353e-01],
#        [-5.37841353e-01, -3.36155967e-01],
#        [ 6.03693619e-01,  2.01222123e-01],
#        [ 2.01222123e-01,  6.03693619e-01],
#        [ 6.03690309e-01, -2.01248270e-01],
#        [-2.01248270e-01,  6.03690309e-01],
#        [ 2.01218813e-01, -6.03710938e-01],
#        [-6.03710938e-01,  2.01218813e-01],
#        [-2.01244959e-01, -6.03707628e-01],
#        [-6.03707628e-01, -2.01244959e-01]]), 'NbfLEDs': 21, 'NdfLEDs': 68}
# torch.Size([40, 40])

# %%
# Define network/reconstruction
print(device)
network = model.model(metadata, device=device)

# Setup optimizer
tvars = network.network.parameters()
if optim == 'adam':
    optimizer = torch.optim.Adam(tvars, lr=step_size)
elif optim == 'sgd':
    optimizer = torch.optim.SGD(tvars, lr=step_size)
else:
    assert False, 'Not valid optimizer (sgd, adam)'

# Setup loss function
if loss == "mse":
    loss_func = lambda x1, x2: torch.mean((x1-x2)**2)
elif loss == "abs":
    loss_func = lambda x1, x2: torch.mean((getAbs(x1)-getAbs(x2))**2)
elif loss == "phase":
    loss_func = lambda x1, x2: torch.mean((getPhase(x1)-getPhase(x2))**2)
else:
    assert False, 'Not valid loss function (try mse)'
# Out:
# cuda:0
# Reconstruction's pixel size (um): 0.414516129032258
# System's pixel size limit (um): 1.285
# Camera's effective pixel size (um): 1.625
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)
# planewaves (89, 40, 40)

# %%
# Setup tensorboard writer
exp_string = 'batch_size={0:d}_stepsize={1:.3f}_loss_fn={8:}_optim={2:}_num_unrolls={3:d}_alpha={4:.3f}_num_df={5:d}_num_bf={6:d}_num_leds={7:d}'.format(batch_size, step_size, optim, num_unrolls, alpha, num_df, num_bf, metadata['Nleds'], loss)
exp_time = get_time_stamp()
exp_dir = './runs/' + exp_time + exp_string
if verbose: print(exp_dir)
if tensorboard: 
    writer = SummaryWriter(exp_dir)

# %% [markdown]
# ## Training Physics-based learned Design

# %%
# training loop
for ii in range(training_iter):
    print('training iteration:', ii, 'out of', training_iter, 'iterations.')
    batch_index = np.mod(ii,num_batches-1)
    input_data, output_data = dataset[batch_index]
    input_data = input_data.unsqueeze(0)
    output_data = output_data.unsqueeze(0)
    # forward evaluation (loop over batches)
    loss_training = 0.
    network.network.zero_grad()
    for bb in range(batch_size):
        zgFlag = bb == 0
        start_time = time.time()
        print('input_data', input_data.shape)
        x0 = network.initialize(input_data.to(device), device=device)
        print(x0)
        xN_tmp, _ = evaluate(network.network, x0, testFlag = False, device = device)
        loss_tmp = loss_func(output_data.to(device),xN_tmp)
        loss_tmp.backward()
        end_time = time.time()
        with torch.no_grad():
            loss_training += loss_tmp

    # gradient and projection updates
    optimizer.step()
    network.projection()


    # testing evaluation
    if np.mod(ii, test_freq) == 0:
        input_data, output_data = dataset[num_batches-1]            
        
        # forward evaluation (loop over batches)
        loss_testing = 0.
        for bb in range(batch_size):
            x0 = network.initialize(input_data.to(device), device = device)
            xN_test, _ = evaluate(network.network, x0, testFlag = True, device = device)
            loss_tmp = loss_func(output_data.to(device),xN_test)
            with torch.no_grad():
                loss_testing += loss_tmp.cpu().numpy()


        # tensorboard writer
        if tensorboard:
            # visualizing
            with torch.no_grad():
                fig = visualizer.visualize(network.grad.C.data.cpu().numpy(), metadata)
            os.system('mkdir -p ' + exp_dir + '/tmp/')
            img_file_path = exp_dir + '/tmp/leds_{0:4d}.png'.format(ii)
            fig.savefig(img_file_path, transparent=True, dpi=150)
            plt.close()
            led_img = mpimg.imread(img_file_path)[...,:3]


            # writing to tensorboard
            writer.add_scalar('Loss/test', loss_testing/batch_size, ii)
            writer.add_scalar('Loss/train', loss_training/batch_size, ii)
            writer.add_image('Visual/leds', led_img, ii, dataformats='HWC')


            # saving checkpoints
            saveDict = {'model_state_dict':network.network.state_dict(),
                        'loss_testing':loss_testing,
                        'loss_training':loss_training,
                        'alpha':alpha,
                        'num_unrolls':num_unrolls,
                        'num_meas':num_meas,
                        'num_bf':num_bf,
                        'num_df':num_df,
                       }             
            torch.save(saveDict, exp_dir + '/ckpt.tar')

    # progress print statement
    print(format_loss_monitor(ii, loss_testing / batch_size, end_time - start_time), end="\r")
# Out:
# training iteration: 0 out of 100 iterations.
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[0.2306, 0.0000],
#          [0.0169, 0.0000],
#          [0.0053, 0.0000],
#          ...,
#          [1.8313, 0.0000],
#          [1.8231, 0.0000],
#          [1.8199, 0.0000]],
#
#         [[0.4545, 0.0000],
#          [1.8207, 0.0000],
#          [1.8276, 0.0000],
#          ...,
#          [1.8083, 0.0000],
#          [1.8218, 0.0000],
#          [1.8240, 0.0000]],
#
#         [[0.4513, 0.0000],
#          [1.8248, 0.0000],
#          [1.8180, 0.0000],
#          ...,
#          [1.8170, 0.0000],
#          [1.8236, 0.0000],
#          [1.8272, 0.0000]],
#
#         ...,
#
#         [[0.4517, 0.0000],
#          [1.8167, 0.0000],
#          [1.8292, 0.0000],
#          ...,
#          [1.8146, 0.0000],
#          [1.8097, 0.0000],
#          [1.8099, 0.0000]],
#
#         [[0.4558, 0.0000],
#          [1.8164, 0.0000],
#          [1.8272, 0.0000],
#          ...,
#          [1.8115, 0.0000],
#          [1.8191, 0.0000],
#          [1.8254, 0.0000]],
#
#         [[0.6508, 0.0000],
#          [1.8263, 0.0000],
#          [1.8256, 0.0000],
#          ...,
#          [1.8290, 0.0000],
#          [1.8057, 0.0000],
#          [1.8314, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 1 out of 100 iterations.time=1.004
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8220, 0.0000],
#          [1.8219, 0.0000],
#          [1.8265, 0.0000],
#          ...,
#          [1.8193, 0.0000],
#          [1.8184, 0.0000],
#          [1.8318, 0.0000]],
#
#         [[1.8168, 0.0000],
#          [1.8286, 0.0000],
#          [1.8266, 0.0000],
#          ...,
#          [1.8135, 0.0000],
#          [1.8209, 0.0000],
#          [1.8192, 0.0000]],
#
#         [[1.8186, 0.0000],
#          [1.8307, 0.0000],
#          [1.8194, 0.0000],
#          ...,
#          [1.8067, 0.0000],
#          [1.8281, 0.0000],
#          [1.8297, 0.0000]],
#
#         ...,
#
#         [[1.8275, 0.0000],
#          [0.0048, 0.0000],
#          [1.8232, 0.0000],
#          ...,
#          [1.8217, 0.0000],
#          [1.8287, 0.0000],
#          [1.8103, 0.0000]],
#
#         [[0.9839, 0.0000],
#          [0.0111, 0.0000],
#          [1.8241, 0.0000],
#          ...,
#          [1.8130, 0.0000],
#          [1.8290, 0.0000],
#          [1.8189, 0.0000]],
#
#         [[0.3081, 0.0000],
#          [0.0387, 0.0000],
#          [1.8085, 0.0000],
#          ...,
#          [1.8241, 0.0000],
#          [1.8235, 0.0000],
#          [1.8174, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 2 out of 100 iterations.time=0.851
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8325, 0.0000],
#          [1.8319, 0.0000],
#          [1.8189, 0.0000],
#          ...,
#          [1.8166, 0.0000],
#          [1.8197, 0.0000],
#          [0.0048, 0.0000]],
#
#         [[1.8096, 0.0000],
#          [1.8218, 0.0000],
#          [1.8216, 0.0000],
#          ...,
#          [1.8275, 0.0000],
#          [1.8186, 0.0000],
#          [1.8288, 0.0000]],
#
#         [[1.8258, 0.0000],
#          [1.8172, 0.0000],
#          [1.8247, 0.0000],
#          ...,
#          [1.8199, 0.0000],
#          [1.8340, 0.0000],
#          [1.8229, 0.0000]],
#
#         ...,
#
#         [[1.8207, 0.0000],
#          [1.8190, 0.0000],
#          [1.8256, 0.0000],
#          ...,
#          [0.0050, 0.0000],
#          [0.0392, 0.0000],
#          [1.8273, 0.0000]],
#
#         [[1.8204, 0.0000],
#          [1.8187, 0.0000],
#          [1.8163, 0.0000],
#          ...,
#          [1.8251, 0.0000],
#          [0.1350, 0.0000],
#          [0.0054, 0.0000]],
#
#         [[1.8174, 0.0000],
#          [1.8248, 0.0000],
#          [1.8110, 0.0000],
#          ...,
#          [1.8231, 0.0000],
#          [1.8230, 0.0000],
#          [1.8304, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 3 out of 100 iterations.time=0.838
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[0.8288, 0.0000],
#          [1.8306, 0.0000],
#          [0.0050, 0.0000],
#          ...,
#          [1.8191, 0.0000],
#          [1.8224, 0.0000],
#          [1.8292, 0.0000]],
#
#         [[1.8252, 0.0000],
#          [0.0059, 0.0000],
#          [0.1348, 0.0000],
#          ...,
#          [1.8186, 0.0000],
#          [1.8310, 0.0000],
#          [1.8332, 0.0000]],
#
#         [[0.0304, 0.0000],
#          [0.0046, 0.0000],
#          [1.8226, 0.0000],
#          ...,
#          [1.8138, 0.0000],
#          [1.8117, 0.0000],
#          [1.8225, 0.0000]],
#
#         ...,
#
#         [[1.8274, 0.0000],
#          [1.8160, 0.0000],
#          [1.8104, 0.0000],
#          ...,
#          [1.7995, 0.0000],
#          [1.8178, 0.0000],
#          [1.8174, 0.0000]],
#
#         [[1.8295, 0.0000],
#          [1.8137, 0.0000],
#          [1.8224, 0.0000],
#          ...,
#          [1.8220, 0.0000],
#          [1.8101, 0.0000],
#          [1.8273, 0.0000]],
#
#         [[1.8273, 0.0000],
#          [1.8303, 0.0000],
#          [1.8136, 0.0000],
#          ...,
#          [1.8323, 0.0000],
#          [1.8187, 0.0000],
#          [1.8223, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 4 out of 100 iterations.time=0.848
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8139, 0.0000],
#          [1.8227, 0.0000],
#          [1.8296, 0.0000],
#          ...,
#          [1.8170, 0.0000],
#          [1.8175, 0.0000],
#          [1.8284, 0.0000]],
#
#         [[1.8160, 0.0000],
#          [1.8237, 0.0000],
#          [1.8127, 0.0000],
#          ...,
#          [1.8239, 0.0000],
#          [1.8287, 0.0000],
#          [1.8254, 0.0000]],
#
#         [[1.8072, 0.0000],
#          [1.8226, 0.0000],
#          [1.8266, 0.0000],
#          ...,
#          [1.8340, 0.0000],
#          [1.8229, 0.0000],
#          [1.8199, 0.0000]],
#
#         ...,
#
#         [[1.8198, 0.0000],
#          [1.8246, 0.0000],
#          [0.0399, 0.0000],
#          ...,
#          [1.8212, 0.0000],
#          [1.8188, 0.0000],
#          [1.8273, 0.0000]],
#
#         [[0.0154, 0.0000],
#          [0.0050, 0.0000],
#          [0.0779, 0.0000],
#          ...,
#          [1.8307, 0.0000],
#          [1.8217, 0.0000],
#          [1.8204, 0.0000]],
#
#         [[0.0630, 0.0000],
#          [1.8201, 0.0000],
#          [1.8223, 0.0000],
#          ...,
#          [1.8241, 0.0000],
#          [1.8197, 0.0000],
#          [1.8285, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 5 out of 100 iterations.time=0.836
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8119, 0.0000],
#          [1.8226, 0.0000],
#          [1.8225, 0.0000],
#          ...,
#          [1.8148, 0.0000],
#          [1.8249, 0.0000],
#          [1.8262, 0.0000]],
#
#         [[1.8259, 0.0000],
#          [1.8186, 0.0000],
#          [1.8216, 0.0000],
#          ...,
#          [1.8227, 0.0000],
#          [1.8313, 0.0000],
#          [1.8231, 0.0000]],
#
#         [[1.8288, 0.0000],
#          [1.8203, 0.0000],
#          [1.8218, 0.0000],
#          ...,
#          [1.8325, 0.0000],
#          [1.8247, 0.0000],
#          [1.8314, 0.0000]],
#
#         ...,
#
#         [[0.0064, 0.0000],
#          [1.8350, 0.0000],
#          [0.3084, 0.0000],
#          ...,
#          [1.8380, 0.0000],
#          [1.8299, 0.0000],
#          [1.8168, 0.0000]],
#
#         [[1.8245, 0.0000],
#          [0.1413, 0.0000],
#          [0.0043, 0.0000],
#          ...,
#          [1.8249, 0.0000],
#          [1.8378, 0.0000],
#          [0.9541, 0.0000]],
#
#         [[0.0046, 0.0000],
#          [0.0051, 0.0000],
#          [1.8156, 0.0000],
#          ...,
#          [1.8242, 0.0000],
#          [1.8329, 0.0000],
#          [0.0818, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 6 out of 100 iterations.time=0.856
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8243, 0.0000],
#          [1.8294, 0.0000],
#          [1.8263, 0.0000],
#          ...,
#          [1.8144, 0.0000],
#          [1.8286, 0.0000],
#          [1.8263, 0.0000]],
#
#         [[1.8289, 0.0000],
#          [1.8126, 0.0000],
#          [1.8385, 0.0000],
#          ...,
#          [1.8146, 0.0000],
#          [1.8216, 0.0000],
#          [1.8172, 0.0000]],
#
#         [[1.8351, 0.0000],
#          [1.8168, 0.0000],
#          [1.8220, 0.0000],
#          ...,
#          [1.8192, 0.0000],
#          [1.8251, 0.0000],
#          [1.8213, 0.0000]],
#
#         ...,
#
#         [[1.8274, 0.0000],
#          [1.8322, 0.0000],
#          [1.8201, 0.0000],
#          ...,
#          [1.8282, 0.0000],
#          [1.8080, 0.0000],
#          [1.8299, 0.0000]],
#
#         [[1.8279, 0.0000],
#          [1.8201, 0.0000],
#          [1.8216, 0.0000],
#          ...,
#          [1.8304, 0.0000],
#          [1.8271, 0.0000],
#          [1.8198, 0.0000]],
#
#         [[1.8187, 0.0000],
#          [1.8153, 0.0000],
#          [1.8261, 0.0000],
#          ...,
#          [0.1162, 0.0000],
#          [1.8157, 0.0000],
#          [1.8196, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 7 out of 100 iterations.time=0.848
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8167, 0.0000],
#          [1.8337, 0.0000],
#          [1.8133, 0.0000],
#          ...,
#          [1.8237, 0.0000],
#          [1.8329, 0.0000],
#          [1.8201, 0.0000]],
#
#         [[1.8260, 0.0000],
#          [1.8163, 0.0000],
#          [1.8244, 0.0000],
#          ...,
#          [1.8280, 0.0000],
#          [1.8243, 0.0000],
#          [1.8249, 0.0000]],
#
#         [[1.8166, 0.0000],
#          [1.8249, 0.0000],
#          [1.8230, 0.0000],
#          ...,
#          [1.8146, 0.0000],
#          [1.8098, 0.0000],
#          [1.8278, 0.0000]],
#
#         ...,
#
#         [[0.0051, 0.0000],
#          [1.8271, 0.0000],
#          [1.8162, 0.0000],
#          ...,
#          [1.8163, 0.0000],
#          [0.0049, 0.0000],
#          [1.8100, 0.0000]],
#
#         [[0.0053, 0.0000],
#          [0.0836, 0.0000],
#          [1.8249, 0.0000],
#          ...,
#          [1.8175, 0.0000],
#          [0.0050, 0.0000],
#          [1.8111, 0.0000]],
#
#         [[1.8256, 0.0000],
#          [0.0052, 0.0000],
#          [1.8254, 0.0000],
#          ...,
#          [1.8172, 0.0000],
#          [0.0108, 0.0000],
#          [0.6130, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 8 out of 100 iterations.time=0.846
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8234, 0.0000],
#          [1.8204, 0.0000],
#          [1.8312, 0.0000],
#          ...,
#          [0.0635, 0.0000],
#          [1.8312, 0.0000],
#          [0.0047, 0.0000]],
#
#         [[1.8167, 0.0000],
#          [1.8158, 0.0000],
#          [1.8185, 0.0000],
#          ...,
#          [0.0050, 0.0000],
#          [1.8310, 0.0000],
#          [0.0363, 0.0000]],
#
#         [[1.8220, 0.0000],
#          [1.8252, 0.0000],
#          [1.8174, 0.0000],
#          ...,
#          [0.0067, 0.0000],
#          [0.0724, 0.0000],
#          [1.8220, 0.0000]],
#
#         ...,
#
#         [[1.8257, 0.0000],
#          [1.8338, 0.0000],
#          [1.8121, 0.0000],
#          ...,
#          [1.8375, 0.0000],
#          [1.8129, 0.0000],
#          [1.8199, 0.0000]],
#
#         [[1.8162, 0.0000],
#          [1.8277, 0.0000],
#          [1.8246, 0.0000],
#          ...,
#          [1.8179, 0.0000],
#          [1.8265, 0.0000],
#          [1.8169, 0.0000]],
#
#         [[1.8149, 0.0000],
#          [1.8212, 0.0000],
#          [1.8261, 0.0000],
#          ...,
#          [1.8233, 0.0000],
#          [1.8162, 0.0000],
#          [1.8222, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 9 out of 100 iterations.time=0.932
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[0.2306, 0.0000],
#          [0.0169, 0.0000],
#          [0.0053, 0.0000],
#          ...,
#          [1.8313, 0.0000],
#          [1.8231, 0.0000],
#          [1.8199, 0.0000]],
#
#         [[0.4545, 0.0000],
#          [1.8207, 0.0000],
#          [1.8276, 0.0000],
#          ...,
#          [1.8083, 0.0000],
#          [1.8218, 0.0000],
#          [1.8240, 0.0000]],
#
#         [[0.4513, 0.0000],
#          [1.8248, 0.0000],
#          [1.8180, 0.0000],
#          ...,
#          [1.8170, 0.0000],
#          [1.8236, 0.0000],
#          [1.8272, 0.0000]],
#
#         ...,
#
#         [[0.4517, 0.0000],
#          [1.8167, 0.0000],
#          [1.8292, 0.0000],
#          ...,
#          [1.8146, 0.0000],
#          [1.8097, 0.0000],
#          [1.8099, 0.0000]],
#
#         [[0.4558, 0.0000],
#          [1.8164, 0.0000],
#          [1.8272, 0.0000],
#          ...,
#          [1.8115, 0.0000],
#          [1.8191, 0.0000],
#          [1.8254, 0.0000]],
#
#         [[0.6508, 0.0000],
#          [1.8263, 0.0000],
#          [1.8256, 0.0000],
#          ...,
#          [1.8290, 0.0000],
#          [1.8057, 0.0000],
#          [1.8314, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 10 out of 100 iterations.ime=0.872
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8220, 0.0000],
#          [1.8219, 0.0000],
#          [1.8265, 0.0000],
#          ...,
#          [1.8193, 0.0000],
#          [1.8184, 0.0000],
#          [1.8318, 0.0000]],
#
#         [[1.8168, 0.0000],
#          [1.8286, 0.0000],
#          [1.8266, 0.0000],
#          ...,
#          [1.8135, 0.0000],
#          [1.8209, 0.0000],
#          [1.8192, 0.0000]],
#
#         [[1.8186, 0.0000],
#          [1.8307, 0.0000],
#          [1.8194, 0.0000],
#          ...,
#          [1.8067, 0.0000],
#          [1.8281, 0.0000],
#          [1.8297, 0.0000]],
#
#         ...,
#
#         [[1.8275, 0.0000],
#          [0.0048, 0.0000],
#          [1.8232, 0.0000],
#          ...,
#          [1.8217, 0.0000],
#          [1.8287, 0.0000],
#          [1.8103, 0.0000]],
#
#         [[0.9839, 0.0000],
#          [0.0111, 0.0000],
#          [1.8241, 0.0000],
#          ...,
#          [1.8130, 0.0000],
#          [1.8290, 0.0000],
#          [1.8189, 0.0000]],
#
#         [[0.3081, 0.0000],
#          [0.0387, 0.0000],
#          [1.8085, 0.0000],
#          ...,
#          [1.8241, 0.0000],
#          [1.8235, 0.0000],
#          [1.8174, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 11 out of 100 iterations.ime=0.852
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8325, 0.0000],
#          [1.8319, 0.0000],
#          [1.8189, 0.0000],
#          ...,
#          [1.8166, 0.0000],
#          [1.8197, 0.0000],
#          [0.0048, 0.0000]],
#
#         [[1.8096, 0.0000],
#          [1.8218, 0.0000],
#          [1.8216, 0.0000],
#          ...,
#          [1.8275, 0.0000],
#          [1.8186, 0.0000],
#          [1.8288, 0.0000]],
#
#         [[1.8258, 0.0000],
#          [1.8172, 0.0000],
#          [1.8247, 0.0000],
#          ...,
#          [1.8199, 0.0000],
#          [1.8340, 0.0000],
#          [1.8229, 0.0000]],
#
#         ...,
#
#         [[1.8207, 0.0000],
#          [1.8190, 0.0000],
#          [1.8256, 0.0000],
#          ...,
#          [0.0050, 0.0000],
#          [0.0392, 0.0000],
#          [1.8273, 0.0000]],
#
#         [[1.8204, 0.0000],
#          [1.8187, 0.0000],
#          [1.8163, 0.0000],
#          ...,
#          [1.8251, 0.0000],
#          [0.1350, 0.0000],
#          [0.0054, 0.0000]],
#
#         [[1.8174, 0.0000],
#          [1.8248, 0.0000],
#          [1.8110, 0.0000],
#          ...,
#          [1.8231, 0.0000],
#          [1.8230, 0.0000],
#          [1.8304, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 12 out of 100 iterations.ime=0.906
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[0.8288, 0.0000],
#          [1.8306, 0.0000],
#          [0.0050, 0.0000],
#          ...,
#          [1.8191, 0.0000],
#          [1.8224, 0.0000],
#          [1.8292, 0.0000]],
#
#         [[1.8252, 0.0000],
#          [0.0059, 0.0000],
#          [0.1348, 0.0000],
#          ...,
#          [1.8186, 0.0000],
#          [1.8310, 0.0000],
#          [1.8332, 0.0000]],
#
#         [[0.0304, 0.0000],
#          [0.0046, 0.0000],
#          [1.8226, 0.0000],
#          ...,
#          [1.8138, 0.0000],
#          [1.8117, 0.0000],
#          [1.8225, 0.0000]],
#
#         ...,
#
#         [[1.8274, 0.0000],
#          [1.8160, 0.0000],
#          [1.8104, 0.0000],
#          ...,
#          [1.7995, 0.0000],
#          [1.8178, 0.0000],
#          [1.8174, 0.0000]],
#
#         [[1.8295, 0.0000],
#          [1.8137, 0.0000],
#          [1.8224, 0.0000],
#          ...,
#          [1.8220, 0.0000],
#          [1.8101, 0.0000],
#          [1.8273, 0.0000]],
#
#         [[1.8273, 0.0000],
#          [1.8303, 0.0000],
#          [1.8136, 0.0000],
#          ...,
#          [1.8323, 0.0000],
#          [1.8187, 0.0000],
#          [1.8223, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 13 out of 100 iterations.ime=0.845
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8139, 0.0000],
#          [1.8227, 0.0000],
#          [1.8296, 0.0000],
#          ...,
#          [1.8170, 0.0000],
#          [1.8175, 0.0000],
#          [1.8284, 0.0000]],
#
#         [[1.8160, 0.0000],
#          [1.8237, 0.0000],
#          [1.8127, 0.0000],
#          ...,
#          [1.8239, 0.0000],
#          [1.8287, 0.0000],
#          [1.8254, 0.0000]],
#
#         [[1.8072, 0.0000],
#          [1.8226, 0.0000],
#          [1.8266, 0.0000],
#          ...,
#          [1.8340, 0.0000],
#          [1.8229, 0.0000],
#          [1.8199, 0.0000]],
#
#         ...,
#
#         [[1.8198, 0.0000],
#          [1.8246, 0.0000],
#          [0.0399, 0.0000],
#          ...,
#          [1.8212, 0.0000],
#          [1.8188, 0.0000],
#          [1.8273, 0.0000]],
#
#         [[0.0154, 0.0000],
#          [0.0050, 0.0000],
#          [0.0779, 0.0000],
#          ...,
#          [1.8307, 0.0000],
#          [1.8217, 0.0000],
#          [1.8204, 0.0000]],
#
#         [[0.0630, 0.0000],
#          [1.8201, 0.0000],
#          [1.8223, 0.0000],
#          ...,
#          [1.8241, 0.0000],
#          [1.8197, 0.0000],
#          [1.8285, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 14 out of 100 iterations.ime=0.898
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8119, 0.0000],
#          [1.8226, 0.0000],
#          [1.8225, 0.0000],
#          ...,
#          [1.8148, 0.0000],
#          [1.8249, 0.0000],
#          [1.8262, 0.0000]],
#
#         [[1.8259, 0.0000],
#          [1.8186, 0.0000],
#          [1.8216, 0.0000],
#          ...,
#          [1.8227, 0.0000],
#          [1.8313, 0.0000],
#          [1.8231, 0.0000]],
#
#         [[1.8288, 0.0000],
#          [1.8203, 0.0000],
#          [1.8218, 0.0000],
#          ...,
#          [1.8325, 0.0000],
#          [1.8247, 0.0000],
#          [1.8314, 0.0000]],
#
#         ...,
#
#         [[0.0064, 0.0000],
#          [1.8350, 0.0000],
#          [0.3084, 0.0000],
#          ...,
#          [1.8380, 0.0000],
#          [1.8299, 0.0000],
#          [1.8168, 0.0000]],
#
#         [[1.8245, 0.0000],
#          [0.1413, 0.0000],
#          [0.0043, 0.0000],
#          ...,
#          [1.8249, 0.0000],
#          [1.8378, 0.0000],
#          [0.9541, 0.0000]],
#
#         [[0.0046, 0.0000],
#          [0.0051, 0.0000],
#          [1.8156, 0.0000],
#          ...,
#          [1.8242, 0.0000],
#          [1.8329, 0.0000],
#          [0.0818, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 15 out of 100 iterations.ime=0.831
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8243, 0.0000],
#          [1.8294, 0.0000],
#          [1.8263, 0.0000],
#          ...,
#          [1.8144, 0.0000],
#          [1.8286, 0.0000],
#          [1.8263, 0.0000]],
#
#         [[1.8289, 0.0000],
#          [1.8126, 0.0000],
#          [1.8385, 0.0000],
#          ...,
#          [1.8146, 0.0000],
#          [1.8216, 0.0000],
#          [1.8172, 0.0000]],
#
#         [[1.8351, 0.0000],
#          [1.8168, 0.0000],
#          [1.8220, 0.0000],
#          ...,
#          [1.8192, 0.0000],
#          [1.8251, 0.0000],
#          [1.8213, 0.0000]],
#
#         ...,
#
#         [[1.8274, 0.0000],
#          [1.8322, 0.0000],
#          [1.8201, 0.0000],
#          ...,
#          [1.8282, 0.0000],
#          [1.8080, 0.0000],
#          [1.8299, 0.0000]],
#
#         [[1.8279, 0.0000],
#          [1.8201, 0.0000],
#          [1.8216, 0.0000],
#          ...,
#          [1.8304, 0.0000],
#          [1.8271, 0.0000],
#          [1.8198, 0.0000]],
#
#         [[1.8187, 0.0000],
#          [1.8153, 0.0000],
#          [1.8261, 0.0000],
#          ...,
#          [0.1162, 0.0000],
#          [1.8157, 0.0000],
#          [1.8196, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 16 out of 100 iterations.ime=0.825
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8167, 0.0000],
#          [1.8337, 0.0000],
#          [1.8133, 0.0000],
#          ...,
#          [1.8237, 0.0000],
#          [1.8329, 0.0000],
#          [1.8201, 0.0000]],
#
#         [[1.8260, 0.0000],
#          [1.8163, 0.0000],
#          [1.8244, 0.0000],
#          ...,
#          [1.8280, 0.0000],
#          [1.8243, 0.0000],
#          [1.8249, 0.0000]],
#
#         [[1.8166, 0.0000],
#          [1.8249, 0.0000],
#          [1.8230, 0.0000],
#          ...,
#          [1.8146, 0.0000],
#          [1.8098, 0.0000],
#          [1.8278, 0.0000]],
#
#         ...,
#
#         [[0.0051, 0.0000],
#          [1.8271, 0.0000],
#          [1.8162, 0.0000],
#          ...,
#          [1.8163, 0.0000],
#          [0.0049, 0.0000],
#          [1.8100, 0.0000]],
#
#         [[0.0053, 0.0000],
#          [0.0836, 0.0000],
#          [1.8249, 0.0000],
#          ...,
#          [1.8175, 0.0000],
#          [0.0050, 0.0000],
#          [1.8111, 0.0000]],
#
#         [[1.8256, 0.0000],
#          [0.0052, 0.0000],
#          [1.8254, 0.0000],
#          ...,
#          [1.8172, 0.0000],
#          [0.0108, 0.0000],
#          [0.6130, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 17 out of 100 iterations.ime=0.852
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8234, 0.0000],
#          [1.8204, 0.0000],
#          [1.8312, 0.0000],
#          ...,
#          [0.0635, 0.0000],
#          [1.8312, 0.0000],
#          [0.0047, 0.0000]],
#
#         [[1.8167, 0.0000],
#          [1.8158, 0.0000],
#          [1.8185, 0.0000],
#          ...,
#          [0.0050, 0.0000],
#          [1.8310, 0.0000],
#          [0.0363, 0.0000]],
#
#         [[1.8220, 0.0000],
#          [1.8252, 0.0000],
#          [1.8174, 0.0000],
#          ...,
#          [0.0067, 0.0000],
#          [0.0724, 0.0000],
#          [1.8220, 0.0000]],
#
#         ...,
#
#         [[1.8257, 0.0000],
#          [1.8338, 0.0000],
#          [1.8121, 0.0000],
#          ...,
#          [1.8375, 0.0000],
#          [1.8129, 0.0000],
#          [1.8199, 0.0000]],
#
#         [[1.8162, 0.0000],
#          [1.8277, 0.0000],
#          [1.8246, 0.0000],
#          ...,
#          [1.8179, 0.0000],
#          [1.8265, 0.0000],
#          [1.8169, 0.0000]],
#
#         [[1.8149, 0.0000],
#          [1.8212, 0.0000],
#          [1.8261, 0.0000],
#          ...,
#          [1.8233, 0.0000],
#          [1.8162, 0.0000],
#          [1.8222, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 18 out of 100 iterations.ime=0.863
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[0.2306, 0.0000],
#          [0.0169, 0.0000],
#          [0.0053, 0.0000],
#          ...,
#          [1.8313, 0.0000],
#          [1.8231, 0.0000],
#          [1.8199, 0.0000]],
#
#         [[0.4545, 0.0000],
#          [1.8207, 0.0000],
#          [1.8276, 0.0000],
#          ...,
#          [1.8083, 0.0000],
#          [1.8218, 0.0000],
#          [1.8240, 0.0000]],
#
#         [[0.4513, 0.0000],
#          [1.8248, 0.0000],
#          [1.8180, 0.0000],
#          ...,
#          [1.8170, 0.0000],
#          [1.8236, 0.0000],
#          [1.8272, 0.0000]],
#
#         ...,
#
#         [[0.4517, 0.0000],
#          [1.8167, 0.0000],
#          [1.8292, 0.0000],
#          ...,
#          [1.8146, 0.0000],
#          [1.8097, 0.0000],
#          [1.8099, 0.0000]],
#
#         [[0.4558, 0.0000],
#          [1.8164, 0.0000],
#          [1.8272, 0.0000],
#          ...,
#          [1.8115, 0.0000],
#          [1.8191, 0.0000],
#          [1.8254, 0.0000]],
#
#         [[0.6508, 0.0000],
#          [1.8263, 0.0000],
#          [1.8256, 0.0000],
#          ...,
#          [1.8290, 0.0000],
#          [1.8057, 0.0000],
#          [1.8314, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 19 out of 100 iterations.ime=0.913
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8220, 0.0000],
#          [1.8219, 0.0000],
#          [1.8265, 0.0000],
#          ...,
#          [1.8193, 0.0000],
#          [1.8184, 0.0000],
#          [1.8318, 0.0000]],
#
#         [[1.8168, 0.0000],
#          [1.8286, 0.0000],
#          [1.8266, 0.0000],
#          ...,
#          [1.8135, 0.0000],
#          [1.8209, 0.0000],
#          [1.8192, 0.0000]],
#
#         [[1.8186, 0.0000],
#          [1.8307, 0.0000],
#          [1.8194, 0.0000],
#          ...,
#          [1.8067, 0.0000],
#          [1.8281, 0.0000],
#          [1.8297, 0.0000]],
#
#         ...,
#
#         [[1.8275, 0.0000],
#          [0.0048, 0.0000],
#          [1.8232, 0.0000],
#          ...,
#          [1.8217, 0.0000],
#          [1.8287, 0.0000],
#          [1.8103, 0.0000]],
#
#         [[0.9839, 0.0000],
#          [0.0111, 0.0000],
#          [1.8241, 0.0000],
#          ...,
#          [1.8130, 0.0000],
#          [1.8290, 0.0000],
#          [1.8189, 0.0000]],
#
#         [[0.3081, 0.0000],
#          [0.0387, 0.0000],
#          [1.8085, 0.0000],
#          ...,
#          [1.8241, 0.0000],
#          [1.8235, 0.0000],
#          [1.8174, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 20 out of 100 iterations.ime=0.893
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8325, 0.0000],
#          [1.8319, 0.0000],
#          [1.8189, 0.0000],
#          ...,
#          [1.8166, 0.0000],
#          [1.8197, 0.0000],
#          [0.0048, 0.0000]],
#
#         [[1.8096, 0.0000],
#          [1.8218, 0.0000],
#          [1.8216, 0.0000],
#          ...,
#          [1.8275, 0.0000],
#          [1.8186, 0.0000],
#          [1.8288, 0.0000]],
#
#         [[1.8258, 0.0000],
#          [1.8172, 0.0000],
#          [1.8247, 0.0000],
#          ...,
#          [1.8199, 0.0000],
#          [1.8340, 0.0000],
#          [1.8229, 0.0000]],
#
#         ...,
#
#         [[1.8207, 0.0000],
#          [1.8190, 0.0000],
#          [1.8256, 0.0000],
#          ...,
#          [0.0050, 0.0000],
#          [0.0392, 0.0000],
#          [1.8273, 0.0000]],
#
#         [[1.8204, 0.0000],
#          [1.8187, 0.0000],
#          [1.8163, 0.0000],
#          ...,
#          [1.8251, 0.0000],
#          [0.1350, 0.0000],
#          [0.0054, 0.0000]],
#
#         [[1.8174, 0.0000],
#          [1.8248, 0.0000],
#          [1.8110, 0.0000],
#          ...,
#          [1.8231, 0.0000],
#          [1.8230, 0.0000],
#          [1.8304, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 21 out of 100 iterations.ime=0.892
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[0.8288, 0.0000],
#          [1.8306, 0.0000],
#          [0.0050, 0.0000],
#          ...,
#          [1.8191, 0.0000],
#          [1.8224, 0.0000],
#          [1.8292, 0.0000]],
#
#         [[1.8252, 0.0000],
#          [0.0059, 0.0000],
#          [0.1348, 0.0000],
#          ...,
#          [1.8186, 0.0000],
#          [1.8310, 0.0000],
#          [1.8332, 0.0000]],
#
#         [[0.0304, 0.0000],
#          [0.0046, 0.0000],
#          [1.8226, 0.0000],
#          ...,
#          [1.8138, 0.0000],
#          [1.8117, 0.0000],
#          [1.8225, 0.0000]],
#
#         ...,
#
#         [[1.8274, 0.0000],
#          [1.8160, 0.0000],
#          [1.8104, 0.0000],
#          ...,
#          [1.7995, 0.0000],
#          [1.8178, 0.0000],
#          [1.8174, 0.0000]],
#
#         [[1.8295, 0.0000],
#          [1.8137, 0.0000],
#          [1.8224, 0.0000],
#          ...,
#          [1.8220, 0.0000],
#          [1.8101, 0.0000],
#          [1.8273, 0.0000]],
#
#         [[1.8273, 0.0000],
#          [1.8303, 0.0000],
#          [1.8136, 0.0000],
#          ...,
#          [1.8323, 0.0000],
#          [1.8187, 0.0000],
#          [1.8223, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 22 out of 100 iterations.ime=0.950
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8139, 0.0000],
#          [1.8227, 0.0000],
#          [1.8296, 0.0000],
#          ...,
#          [1.8170, 0.0000],
#          [1.8175, 0.0000],
#          [1.8284, 0.0000]],
#
#         [[1.8160, 0.0000],
#          [1.8237, 0.0000],
#          [1.8127, 0.0000],
#          ...,
#          [1.8239, 0.0000],
#          [1.8287, 0.0000],
#          [1.8254, 0.0000]],
#
#         [[1.8072, 0.0000],
#          [1.8226, 0.0000],
#          [1.8266, 0.0000],
#          ...,
#          [1.8340, 0.0000],
#          [1.8229, 0.0000],
#          [1.8199, 0.0000]],
#
#         ...,
#
#         [[1.8198, 0.0000],
#          [1.8246, 0.0000],
#          [0.0399, 0.0000],
#          ...,
#          [1.8212, 0.0000],
#          [1.8188, 0.0000],
#          [1.8273, 0.0000]],
#
#         [[0.0154, 0.0000],
#          [0.0050, 0.0000],
#          [0.0779, 0.0000],
#          ...,
#          [1.8307, 0.0000],
#          [1.8217, 0.0000],
#          [1.8204, 0.0000]],
#
#         [[0.0630, 0.0000],
#          [1.8201, 0.0000],
#          [1.8223, 0.0000],
#          ...,
#          [1.8241, 0.0000],
#          [1.8197, 0.0000],
#          [1.8285, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 23 out of 100 iterations.ime=0.898
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8119, 0.0000],
#          [1.8226, 0.0000],
#          [1.8225, 0.0000],
#          ...,
#          [1.8148, 0.0000],
#          [1.8249, 0.0000],
#          [1.8262, 0.0000]],
#
#         [[1.8259, 0.0000],
#          [1.8186, 0.0000],
#          [1.8216, 0.0000],
#          ...,
#          [1.8227, 0.0000],
#          [1.8313, 0.0000],
#          [1.8231, 0.0000]],
#
#         [[1.8288, 0.0000],
#          [1.8203, 0.0000],
#          [1.8218, 0.0000],
#          ...,
#          [1.8325, 0.0000],
#          [1.8247, 0.0000],
#          [1.8314, 0.0000]],
#
#         ...,
#
#         [[0.0064, 0.0000],
#          [1.8350, 0.0000],
#          [0.3084, 0.0000],
#          ...,
#          [1.8380, 0.0000],
#          [1.8299, 0.0000],
#          [1.8168, 0.0000]],
#
#         [[1.8245, 0.0000],
#          [0.1413, 0.0000],
#          [0.0043, 0.0000],
#          ...,
#          [1.8249, 0.0000],
#          [1.8378, 0.0000],
#          [0.9541, 0.0000]],
#
#         [[0.0046, 0.0000],
#          [0.0051, 0.0000],
#          [1.8156, 0.0000],
#          ...,
#          [1.8242, 0.0000],
#          [1.8329, 0.0000],
#          [0.0818, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 24 out of 100 iterations.ime=0.905
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8243, 0.0000],
#          [1.8294, 0.0000],
#          [1.8263, 0.0000],
#          ...,
#          [1.8144, 0.0000],
#          [1.8286, 0.0000],
#          [1.8263, 0.0000]],
#
#         [[1.8289, 0.0000],
#          [1.8126, 0.0000],
#          [1.8385, 0.0000],
#          ...,
#          [1.8146, 0.0000],
#          [1.8216, 0.0000],
#          [1.8172, 0.0000]],
#
#         [[1.8351, 0.0000],
#          [1.8168, 0.0000],
#          [1.8220, 0.0000],
#          ...,
#          [1.8192, 0.0000],
#          [1.8251, 0.0000],
#          [1.8213, 0.0000]],
#
#         ...,
#
#         [[1.8274, 0.0000],
#          [1.8322, 0.0000],
#          [1.8201, 0.0000],
#          ...,
#          [1.8282, 0.0000],
#          [1.8080, 0.0000],
#          [1.8299, 0.0000]],
#
#         [[1.8279, 0.0000],
#          [1.8201, 0.0000],
#          [1.8216, 0.0000],
#          ...,
#          [1.8304, 0.0000],
#          [1.8271, 0.0000],
#          [1.8198, 0.0000]],
#
#         [[1.8187, 0.0000],
#          [1.8153, 0.0000],
#          [1.8261, 0.0000],
#          ...,
#          [0.1162, 0.0000],
#          [1.8157, 0.0000],
#          [1.8196, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 25 out of 100 iterations.ime=1.700
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8167, 0.0000],
#          [1.8337, 0.0000],
#          [1.8133, 0.0000],
#          ...,
#          [1.8237, 0.0000],
#          [1.8329, 0.0000],
#          [1.8201, 0.0000]],
#
#         [[1.8260, 0.0000],
#          [1.8163, 0.0000],
#          [1.8244, 0.0000],
#          ...,
#          [1.8280, 0.0000],
#          [1.8243, 0.0000],
#          [1.8249, 0.0000]],
#
#         [[1.8166, 0.0000],
#          [1.8249, 0.0000],
#          [1.8230, 0.0000],
#          ...,
#          [1.8146, 0.0000],
#          [1.8098, 0.0000],
#          [1.8278, 0.0000]],
#
#         ...,
#
#         [[0.0051, 0.0000],
#          [1.8271, 0.0000],
#          [1.8162, 0.0000],
#          ...,
#          [1.8163, 0.0000],
#          [0.0049, 0.0000],
#          [1.8100, 0.0000]],
#
#         [[0.0053, 0.0000],
#          [0.0836, 0.0000],
#          [1.8249, 0.0000],
#          ...,
#          [1.8175, 0.0000],
#          [0.0050, 0.0000],
#          [1.8111, 0.0000]],
#
#         [[1.8256, 0.0000],
#          [0.0052, 0.0000],
#          [1.8254, 0.0000],
#          ...,
#          [1.8172, 0.0000],
#          [0.0108, 0.0000],
#          [0.6130, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 26 out of 100 iterations.ime=0.857
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8234, 0.0000],
#          [1.8204, 0.0000],
#          [1.8312, 0.0000],
#          ...,
#          [0.0635, 0.0000],
#          [1.8312, 0.0000],
#          [0.0047, 0.0000]],
#
#         [[1.8167, 0.0000],
#          [1.8158, 0.0000],
#          [1.8185, 0.0000],
#          ...,
#          [0.0050, 0.0000],
#          [1.8310, 0.0000],
#          [0.0363, 0.0000]],
#
#         [[1.8220, 0.0000],
#          [1.8252, 0.0000],
#          [1.8174, 0.0000],
#          ...,
#          [0.0067, 0.0000],
#          [0.0724, 0.0000],
#          [1.8220, 0.0000]],
#
#         ...,
#
#         [[1.8257, 0.0000],
#          [1.8338, 0.0000],
#          [1.8121, 0.0000],
#          ...,
#          [1.8375, 0.0000],
#          [1.8129, 0.0000],
#          [1.8199, 0.0000]],
#
#         [[1.8162, 0.0000],
#          [1.8277, 0.0000],
#          [1.8246, 0.0000],
#          ...,
#          [1.8179, 0.0000],
#          [1.8265, 0.0000],
#          [1.8169, 0.0000]],
#
#         [[1.8149, 0.0000],
#          [1.8212, 0.0000],
#          [1.8261, 0.0000],
#          ...,
#          [1.8233, 0.0000],
#          [1.8162, 0.0000],
#          [1.8222, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 27 out of 100 iterations.ime=0.874
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[0.2306, 0.0000],
#          [0.0169, 0.0000],
#          [0.0053, 0.0000],
#          ...,
#          [1.8313, 0.0000],
#          [1.8231, 0.0000],
#          [1.8199, 0.0000]],
#
#         [[0.4545, 0.0000],
#          [1.8207, 0.0000],
#          [1.8276, 0.0000],
#          ...,
#          [1.8083, 0.0000],
#          [1.8218, 0.0000],
#          [1.8240, 0.0000]],
#
#         [[0.4513, 0.0000],
#          [1.8248, 0.0000],
#          [1.8180, 0.0000],
#          ...,
#          [1.8170, 0.0000],
#          [1.8236, 0.0000],
#          [1.8272, 0.0000]],
#
#         ...,
#
#         [[0.4517, 0.0000],
#          [1.8167, 0.0000],
#          [1.8292, 0.0000],
#          ...,
#          [1.8146, 0.0000],
#          [1.8097, 0.0000],
#          [1.8099, 0.0000]],
#
#         [[0.4558, 0.0000],
#          [1.8164, 0.0000],
#          [1.8272, 0.0000],
#          ...,
#          [1.8115, 0.0000],
#          [1.8191, 0.0000],
#          [1.8254, 0.0000]],
#
#         [[0.6508, 0.0000],
#          [1.8263, 0.0000],
#          [1.8256, 0.0000],
#          ...,
#          [1.8290, 0.0000],
#          [1.8057, 0.0000],
#          [1.8314, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 28 out of 100 iterations.ime=0.862
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8220, 0.0000],
#          [1.8219, 0.0000],
#          [1.8265, 0.0000],
#          ...,
#          [1.8193, 0.0000],
#          [1.8184, 0.0000],
#          [1.8318, 0.0000]],
#
#         [[1.8168, 0.0000],
#          [1.8286, 0.0000],
#          [1.8266, 0.0000],
#          ...,
#          [1.8135, 0.0000],
#          [1.8209, 0.0000],
#          [1.8192, 0.0000]],
#
#         [[1.8186, 0.0000],
#          [1.8307, 0.0000],
#          [1.8194, 0.0000],
#          ...,
#          [1.8067, 0.0000],
#          [1.8281, 0.0000],
#          [1.8297, 0.0000]],
#
#         ...,
#
#         [[1.8275, 0.0000],
#          [0.0048, 0.0000],
#          [1.8232, 0.0000],
#          ...,
#          [1.8217, 0.0000],
#          [1.8287, 0.0000],
#          [1.8103, 0.0000]],
#
#         [[0.9839, 0.0000],
#          [0.0111, 0.0000],
#          [1.8241, 0.0000],
#          ...,
#          [1.8130, 0.0000],
#          [1.8290, 0.0000],
#          [1.8189, 0.0000]],
#
#         [[0.3081, 0.0000],
#          [0.0387, 0.0000],
#          [1.8085, 0.0000],
#          ...,
#          [1.8241, 0.0000],
#          [1.8235, 0.0000],
#          [1.8174, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 29 out of 100 iterations.ime=0.934
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8325, 0.0000],
#          [1.8319, 0.0000],
#          [1.8189, 0.0000],
#          ...,
#          [1.8166, 0.0000],
#          [1.8197, 0.0000],
#          [0.0048, 0.0000]],
#
#         [[1.8096, 0.0000],
#          [1.8218, 0.0000],
#          [1.8216, 0.0000],
#          ...,
#          [1.8275, 0.0000],
#          [1.8186, 0.0000],
#          [1.8288, 0.0000]],
#
#         [[1.8258, 0.0000],
#          [1.8172, 0.0000],
#          [1.8247, 0.0000],
#          ...,
#          [1.8199, 0.0000],
#          [1.8340, 0.0000],
#          [1.8229, 0.0000]],
#
#         ...,
#
#         [[1.8207, 0.0000],
#          [1.8190, 0.0000],
#          [1.8256, 0.0000],
#          ...,
#          [0.0050, 0.0000],
#          [0.0392, 0.0000],
#          [1.8273, 0.0000]],
#
#         [[1.8204, 0.0000],
#          [1.8187, 0.0000],
#          [1.8163, 0.0000],
#          ...,
#          [1.8251, 0.0000],
#          [0.1350, 0.0000],
#          [0.0054, 0.0000]],
#
#         [[1.8174, 0.0000],
#          [1.8248, 0.0000],
#          [1.8110, 0.0000],
#          ...,
#          [1.8231, 0.0000],
#          [1.8230, 0.0000],
#          [1.8304, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 30 out of 100 iterations.ime=0.968
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[0.8288, 0.0000],
#          [1.8306, 0.0000],
#          [0.0050, 0.0000],
#          ...,
#          [1.8191, 0.0000],
#          [1.8224, 0.0000],
#          [1.8292, 0.0000]],
#
#         [[1.8252, 0.0000],
#          [0.0059, 0.0000],
#          [0.1348, 0.0000],
#          ...,
#          [1.8186, 0.0000],
#          [1.8310, 0.0000],
#          [1.8332, 0.0000]],
#
#         [[0.0304, 0.0000],
#          [0.0046, 0.0000],
#          [1.8226, 0.0000],
#          ...,
#          [1.8138, 0.0000],
#          [1.8117, 0.0000],
#          [1.8225, 0.0000]],
#
#         ...,
#
#         [[1.8274, 0.0000],
#          [1.8160, 0.0000],
#          [1.8104, 0.0000],
#          ...,
#          [1.7995, 0.0000],
#          [1.8178, 0.0000],
#          [1.8174, 0.0000]],
#
#         [[1.8295, 0.0000],
#          [1.8137, 0.0000],
#          [1.8224, 0.0000],
#          ...,
#          [1.8220, 0.0000],
#          [1.8101, 0.0000],
#          [1.8273, 0.0000]],
#
#         [[1.8273, 0.0000],
#          [1.8303, 0.0000],
#          [1.8136, 0.0000],
#          ...,
#          [1.8323, 0.0000],
#          [1.8187, 0.0000],
#          [1.8223, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 31 out of 100 iterations.ime=0.983
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8139, 0.0000],
#          [1.8227, 0.0000],
#          [1.8296, 0.0000],
#          ...,
#          [1.8170, 0.0000],
#          [1.8175, 0.0000],
#          [1.8284, 0.0000]],
#
#         [[1.8160, 0.0000],
#          [1.8237, 0.0000],
#          [1.8127, 0.0000],
#          ...,
#          [1.8239, 0.0000],
#          [1.8287, 0.0000],
#          [1.8254, 0.0000]],
#
#         [[1.8072, 0.0000],
#          [1.8226, 0.0000],
#          [1.8266, 0.0000],
#          ...,
#          [1.8340, 0.0000],
#          [1.8229, 0.0000],
#          [1.8199, 0.0000]],
#
#         ...,
#
#         [[1.8198, 0.0000],
#          [1.8246, 0.0000],
#          [0.0399, 0.0000],
#          ...,
#          [1.8212, 0.0000],
#          [1.8188, 0.0000],
#          [1.8273, 0.0000]],
#
#         [[0.0154, 0.0000],
#          [0.0050, 0.0000],
#          [0.0779, 0.0000],
#          ...,
#          [1.8307, 0.0000],
#          [1.8217, 0.0000],
#          [1.8204, 0.0000]],
#
#         [[0.0630, 0.0000],
#          [1.8201, 0.0000],
#          [1.8223, 0.0000],
#          ...,
#          [1.8241, 0.0000],
#          [1.8197, 0.0000],
#          [1.8285, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 32 out of 100 iterations.ime=0.868
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8119, 0.0000],
#          [1.8226, 0.0000],
#          [1.8225, 0.0000],
#          ...,
#          [1.8148, 0.0000],
#          [1.8249, 0.0000],
#          [1.8262, 0.0000]],
#
#         [[1.8259, 0.0000],
#          [1.8186, 0.0000],
#          [1.8216, 0.0000],
#          ...,
#          [1.8227, 0.0000],
#          [1.8313, 0.0000],
#          [1.8231, 0.0000]],
#
#         [[1.8288, 0.0000],
#          [1.8203, 0.0000],
#          [1.8218, 0.0000],
#          ...,
#          [1.8325, 0.0000],
#          [1.8247, 0.0000],
#          [1.8314, 0.0000]],
#
#         ...,
#
#         [[0.0064, 0.0000],
#          [1.8350, 0.0000],
#          [0.3084, 0.0000],
#          ...,
#          [1.8380, 0.0000],
#          [1.8299, 0.0000],
#          [1.8168, 0.0000]],
#
#         [[1.8245, 0.0000],
#          [0.1413, 0.0000],
#          [0.0043, 0.0000],
#          ...,
#          [1.8249, 0.0000],
#          [1.8378, 0.0000],
#          [0.9541, 0.0000]],
#
#         [[0.0046, 0.0000],
#          [0.0051, 0.0000],
#          [1.8156, 0.0000],
#          ...,
#          [1.8242, 0.0000],
#          [1.8329, 0.0000],
#          [0.0818, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 33 out of 100 iterations.ime=0.891
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8243, 0.0000],
#          [1.8294, 0.0000],
#          [1.8263, 0.0000],
#          ...,
#          [1.8144, 0.0000],
#          [1.8286, 0.0000],
#          [1.8263, 0.0000]],
#
#         [[1.8289, 0.0000],
#          [1.8126, 0.0000],
#          [1.8385, 0.0000],
#          ...,
#          [1.8146, 0.0000],
#          [1.8216, 0.0000],
#          [1.8172, 0.0000]],
#
#         [[1.8351, 0.0000],
#          [1.8168, 0.0000],
#          [1.8220, 0.0000],
#          ...,
#          [1.8192, 0.0000],
#          [1.8251, 0.0000],
#          [1.8213, 0.0000]],
#
#         ...,
#
#         [[1.8274, 0.0000],
#          [1.8322, 0.0000],
#          [1.8201, 0.0000],
#          ...,
#          [1.8282, 0.0000],
#          [1.8080, 0.0000],
#          [1.8299, 0.0000]],
#
#         [[1.8279, 0.0000],
#          [1.8201, 0.0000],
#          [1.8216, 0.0000],
#          ...,
#          [1.8304, 0.0000],
#          [1.8271, 0.0000],
#          [1.8198, 0.0000]],
#
#         [[1.8187, 0.0000],
#          [1.8153, 0.0000],
#          [1.8261, 0.0000],
#          ...,
#          [0.1162, 0.0000],
#          [1.8157, 0.0000],
#          [1.8196, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 34 out of 100 iterations.ime=0.926
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8167, 0.0000],
#          [1.8337, 0.0000],
#          [1.8133, 0.0000],
#          ...,
#          [1.8237, 0.0000],
#          [1.8329, 0.0000],
#          [1.8201, 0.0000]],
#
#         [[1.8260, 0.0000],
#          [1.8163, 0.0000],
#          [1.8244, 0.0000],
#          ...,
#          [1.8280, 0.0000],
# ...
#          ...,
#          [1.8163, 0.0000],
#          [0.0049, 0.0000],
#          [1.8100, 0.0000]],
#
#         [[0.0053, 0.0000],
#          [0.0836, 0.0000],
#          [1.8249, 0.0000],
#          ...,
#          [1.8175, 0.0000],
#          [0.0050, 0.0000],
#          [1.8111, 0.0000]],
#
#         [[1.8256, 0.0000],
#          [0.0052, 0.0000],
#          [1.8254, 0.0000],
#          ...,
#          [1.8172, 0.0000],
#          [0.0108, 0.0000],
#          [0.6130, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 89 out of 100 iterations.ime=0.911
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8234, 0.0000],
#          [1.8204, 0.0000],
#          [1.8312, 0.0000],
#          ...,
#          [0.0635, 0.0000],
#          [1.8312, 0.0000],
#          [0.0047, 0.0000]],
#
#         [[1.8167, 0.0000],
#          [1.8158, 0.0000],
#          [1.8185, 0.0000],
#          ...,
#          [0.0050, 0.0000],
#          [1.8310, 0.0000],
#          [0.0363, 0.0000]],
#
#         [[1.8220, 0.0000],
#          [1.8252, 0.0000],
#          [1.8174, 0.0000],
#          ...,
#          [0.0067, 0.0000],
#          [0.0724, 0.0000],
#          [1.8220, 0.0000]],
#
#         ...,
#
#         [[1.8257, 0.0000],
#          [1.8338, 0.0000],
#          [1.8121, 0.0000],
#          ...,
#          [1.8375, 0.0000],
#          [1.8129, 0.0000],
#          [1.8199, 0.0000]],
#
#         [[1.8162, 0.0000],
#          [1.8277, 0.0000],
#          [1.8246, 0.0000],
#          ...,
#          [1.8179, 0.0000],
#          [1.8265, 0.0000],
#          [1.8169, 0.0000]],
#
#         [[1.8149, 0.0000],
#          [1.8212, 0.0000],
#          [1.8261, 0.0000],
#          ...,
#          [1.8233, 0.0000],
#          [1.8162, 0.0000],
#          [1.8222, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 90 out of 100 iterations.ime=0.979
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[0.2306, 0.0000],
#          [0.0169, 0.0000],
#          [0.0053, 0.0000],
#          ...,
#          [1.8313, 0.0000],
#          [1.8231, 0.0000],
#          [1.8199, 0.0000]],
#
#         [[0.4545, 0.0000],
#          [1.8207, 0.0000],
#          [1.8276, 0.0000],
#          ...,
#          [1.8083, 0.0000],
#          [1.8218, 0.0000],
#          [1.8240, 0.0000]],
#
#         [[0.4513, 0.0000],
#          [1.8248, 0.0000],
#          [1.8180, 0.0000],
#          ...,
#          [1.8170, 0.0000],
#          [1.8236, 0.0000],
#          [1.8272, 0.0000]],
#
#         ...,
#
#         [[0.4517, 0.0000],
#          [1.8167, 0.0000],
#          [1.8292, 0.0000],
#          ...,
#          [1.8146, 0.0000],
#          [1.8097, 0.0000],
#          [1.8099, 0.0000]],
#
#         [[0.4558, 0.0000],
#          [1.8164, 0.0000],
#          [1.8272, 0.0000],
#          ...,
#          [1.8115, 0.0000],
#          [1.8191, 0.0000],
#          [1.8254, 0.0000]],
#
#         [[0.6508, 0.0000],
#          [1.8263, 0.0000],
#          [1.8256, 0.0000],
#          ...,
#          [1.8290, 0.0000],
#          [1.8057, 0.0000],
#          [1.8314, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 91 out of 100 iterations.ime=0.896
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8220, 0.0000],
#          [1.8219, 0.0000],
#          [1.8265, 0.0000],
#          ...,
#          [1.8193, 0.0000],
#          [1.8184, 0.0000],
#          [1.8318, 0.0000]],
#
#         [[1.8168, 0.0000],
#          [1.8286, 0.0000],
#          [1.8266, 0.0000],
#          ...,
#          [1.8135, 0.0000],
#          [1.8209, 0.0000],
#          [1.8192, 0.0000]],
#
#         [[1.8186, 0.0000],
#          [1.8307, 0.0000],
#          [1.8194, 0.0000],
#          ...,
#          [1.8067, 0.0000],
#          [1.8281, 0.0000],
#          [1.8297, 0.0000]],
#
#         ...,
#
#         [[1.8275, 0.0000],
#          [0.0048, 0.0000],
#          [1.8232, 0.0000],
#          ...,
#          [1.8217, 0.0000],
#          [1.8287, 0.0000],
#          [1.8103, 0.0000]],
#
#         [[0.9839, 0.0000],
#          [0.0111, 0.0000],
#          [1.8241, 0.0000],
#          ...,
#          [1.8130, 0.0000],
#          [1.8290, 0.0000],
#          [1.8189, 0.0000]],
#
#         [[0.3081, 0.0000],
#          [0.0387, 0.0000],
#          [1.8085, 0.0000],
#          ...,
#          [1.8241, 0.0000],
#          [1.8235, 0.0000],
#          [1.8174, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 92 out of 100 iterations.ime=0.900
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8325, 0.0000],
#          [1.8319, 0.0000],
#          [1.8189, 0.0000],
#          ...,
#          [1.8166, 0.0000],
#          [1.8197, 0.0000],
#          [0.0048, 0.0000]],
#
#         [[1.8096, 0.0000],
#          [1.8218, 0.0000],
#          [1.8216, 0.0000],
#          ...,
#          [1.8275, 0.0000],
#          [1.8186, 0.0000],
#          [1.8288, 0.0000]],
#
#         [[1.8258, 0.0000],
#          [1.8172, 0.0000],
#          [1.8247, 0.0000],
#          ...,
#          [1.8199, 0.0000],
#          [1.8340, 0.0000],
#          [1.8229, 0.0000]],
#
#         ...,
#
#         [[1.8207, 0.0000],
#          [1.8190, 0.0000],
#          [1.8256, 0.0000],
#          ...,
#          [0.0050, 0.0000],
#          [0.0392, 0.0000],
#          [1.8273, 0.0000]],
#
#         [[1.8204, 0.0000],
#          [1.8187, 0.0000],
#          [1.8163, 0.0000],
#          ...,
#          [1.8251, 0.0000],
#          [0.1350, 0.0000],
#          [0.0054, 0.0000]],
#
#         [[1.8174, 0.0000],
#          [1.8248, 0.0000],
#          [1.8110, 0.0000],
#          ...,
#          [1.8231, 0.0000],
#          [1.8230, 0.0000],
#          [1.8304, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 93 out of 100 iterations.ime=0.900
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[0.8288, 0.0000],
#          [1.8306, 0.0000],
#          [0.0050, 0.0000],
#          ...,
#          [1.8191, 0.0000],
#          [1.8224, 0.0000],
#          [1.8292, 0.0000]],
#
#         [[1.8252, 0.0000],
#          [0.0059, 0.0000],
#          [0.1348, 0.0000],
#          ...,
#          [1.8186, 0.0000],
#          [1.8310, 0.0000],
#          [1.8332, 0.0000]],
#
#         [[0.0304, 0.0000],
#          [0.0046, 0.0000],
#          [1.8226, 0.0000],
#          ...,
#          [1.8138, 0.0000],
#          [1.8117, 0.0000],
#          [1.8225, 0.0000]],
#
#         ...,
#
#         [[1.8274, 0.0000],
#          [1.8160, 0.0000],
#          [1.8104, 0.0000],
#          ...,
#          [1.7995, 0.0000],
#          [1.8178, 0.0000],
#          [1.8174, 0.0000]],
#
#         [[1.8295, 0.0000],
#          [1.8137, 0.0000],
#          [1.8224, 0.0000],
#          ...,
#          [1.8220, 0.0000],
#          [1.8101, 0.0000],
#          [1.8273, 0.0000]],
#
#         [[1.8273, 0.0000],
#          [1.8303, 0.0000],
#          [1.8136, 0.0000],
#          ...,
#          [1.8323, 0.0000],
#          [1.8187, 0.0000],
#          [1.8223, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 94 out of 100 iterations.ime=0.913
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8139, 0.0000],
#          [1.8227, 0.0000],
#          [1.8296, 0.0000],
#          ...,
#          [1.8170, 0.0000],
#          [1.8175, 0.0000],
#          [1.8284, 0.0000]],
#
#         [[1.8160, 0.0000],
#          [1.8237, 0.0000],
#          [1.8127, 0.0000],
#          ...,
#          [1.8239, 0.0000],
#          [1.8287, 0.0000],
#          [1.8254, 0.0000]],
#
#         [[1.8072, 0.0000],
#          [1.8226, 0.0000],
#          [1.8266, 0.0000],
#          ...,
#          [1.8340, 0.0000],
#          [1.8229, 0.0000],
#          [1.8199, 0.0000]],
#
#         ...,
#
#         [[1.8198, 0.0000],
#          [1.8246, 0.0000],
#          [0.0399, 0.0000],
#          ...,
#          [1.8212, 0.0000],
#          [1.8188, 0.0000],
#          [1.8273, 0.0000]],
#
#         [[0.0154, 0.0000],
#          [0.0050, 0.0000],
#          [0.0779, 0.0000],
#          ...,
#          [1.8307, 0.0000],
#          [1.8217, 0.0000],
#          [1.8204, 0.0000]],
#
#         [[0.0630, 0.0000],
#          [1.8201, 0.0000],
#          [1.8223, 0.0000],
#          ...,
#          [1.8241, 0.0000],
#          [1.8197, 0.0000],
#          [1.8285, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 95 out of 100 iterations.ime=0.874
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8119, 0.0000],
#          [1.8226, 0.0000],
#          [1.8225, 0.0000],
#          ...,
#          [1.8148, 0.0000],
#          [1.8249, 0.0000],
#          [1.8262, 0.0000]],
#
#         [[1.8259, 0.0000],
#          [1.8186, 0.0000],
#          [1.8216, 0.0000],
#          ...,
#          [1.8227, 0.0000],
#          [1.8313, 0.0000],
#          [1.8231, 0.0000]],
#
#         [[1.8288, 0.0000],
#          [1.8203, 0.0000],
#          [1.8218, 0.0000],
#          ...,
#          [1.8325, 0.0000],
#          [1.8247, 0.0000],
#          [1.8314, 0.0000]],
#
#         ...,
#
#         [[0.0064, 0.0000],
#          [1.8350, 0.0000],
#          [0.3084, 0.0000],
#          ...,
#          [1.8380, 0.0000],
#          [1.8299, 0.0000],
#          [1.8168, 0.0000]],
#
#         [[1.8245, 0.0000],
#          [0.1413, 0.0000],
#          [0.0043, 0.0000],
#          ...,
#          [1.8249, 0.0000],
#          [1.8378, 0.0000],
#          [0.9541, 0.0000]],
#
#         [[0.0046, 0.0000],
#          [0.0051, 0.0000],
#          [1.8156, 0.0000],
#          ...,
#          [1.8242, 0.0000],
#          [1.8329, 0.0000],
#          [0.0818, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 96 out of 100 iterations.ime=0.904
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8243, 0.0000],
#          [1.8294, 0.0000],
#          [1.8263, 0.0000],
#          ...,
#          [1.8144, 0.0000],
#          [1.8286, 0.0000],
#          [1.8263, 0.0000]],
#
#         [[1.8289, 0.0000],
#          [1.8126, 0.0000],
#          [1.8385, 0.0000],
#          ...,
#          [1.8146, 0.0000],
#          [1.8216, 0.0000],
#          [1.8172, 0.0000]],
#
#         [[1.8351, 0.0000],
#          [1.8168, 0.0000],
#          [1.8220, 0.0000],
#          ...,
#          [1.8192, 0.0000],
#          [1.8251, 0.0000],
#          [1.8213, 0.0000]],
#
#         ...,
#
#         [[1.8274, 0.0000],
#          [1.8322, 0.0000],
#          [1.8201, 0.0000],
#          ...,
#          [1.8282, 0.0000],
#          [1.8080, 0.0000],
#          [1.8299, 0.0000]],
#
#         [[1.8279, 0.0000],
#          [1.8201, 0.0000],
#          [1.8216, 0.0000],
#          ...,
#          [1.8304, 0.0000],
#          [1.8271, 0.0000],
#          [1.8198, 0.0000]],
#
#         [[1.8187, 0.0000],
#          [1.8153, 0.0000],
#          [1.8261, 0.0000],
#          ...,
#          [0.1162, 0.0000],
#          [1.8157, 0.0000],
#          [1.8196, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 97 out of 100 iterations.ime=0.918
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8167, 0.0000],
#          [1.8337, 0.0000],
#          [1.8133, 0.0000],
#          ...,
#          [1.8237, 0.0000],
#          [1.8329, 0.0000],
#          [1.8201, 0.0000]],
#
#         [[1.8260, 0.0000],
#          [1.8163, 0.0000],
#          [1.8244, 0.0000],
#          ...,
#          [1.8280, 0.0000],
#          [1.8243, 0.0000],
#          [1.8249, 0.0000]],
#
#         [[1.8166, 0.0000],
#          [1.8249, 0.0000],
#          [1.8230, 0.0000],
#          ...,
#          [1.8146, 0.0000],
#          [1.8098, 0.0000],
#          [1.8278, 0.0000]],
#
#         ...,
#
#         [[0.0051, 0.0000],
#          [1.8271, 0.0000],
#          [1.8162, 0.0000],
#          ...,
#          [1.8163, 0.0000],
#          [0.0049, 0.0000],
#          [1.8100, 0.0000]],
#
#         [[0.0053, 0.0000],
#          [0.0836, 0.0000],
#          [1.8249, 0.0000],
#          ...,
#          [1.8175, 0.0000],
#          [0.0050, 0.0000],
#          [1.8111, 0.0000]],
#
#         [[1.8256, 0.0000],
#          [0.0052, 0.0000],
#          [1.8254, 0.0000],
#          ...,
#          [1.8172, 0.0000],
#          [0.0108, 0.0000],
#          [0.6130, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 98 out of 100 iterations.ime=0.912
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[1.8234, 0.0000],
#          [1.8204, 0.0000],
#          [1.8312, 0.0000],
#          ...,
#          [0.0635, 0.0000],
#          [1.8312, 0.0000],
#          [0.0047, 0.0000]],
#
#         [[1.8167, 0.0000],
#          [1.8158, 0.0000],
#          [1.8185, 0.0000],
#          ...,
#          [0.0050, 0.0000],
#          [1.8310, 0.0000],
#          [0.0363, 0.0000]],
#
#         [[1.8220, 0.0000],
#          [1.8252, 0.0000],
#          [1.8174, 0.0000],
#          ...,
#          [0.0067, 0.0000],
#          [0.0724, 0.0000],
#          [1.8220, 0.0000]],
#
#         ...,
#
#         [[1.8257, 0.0000],
#          [1.8338, 0.0000],
#          [1.8121, 0.0000],
#          ...,
#          [1.8375, 0.0000],
#          [1.8129, 0.0000],
#          [1.8199, 0.0000]],
#
#         [[1.8162, 0.0000],
#          [1.8277, 0.0000],
#          [1.8246, 0.0000],
#          ...,
#          [1.8179, 0.0000],
#          [1.8265, 0.0000],
#          [1.8169, 0.0000]],
#
#         [[1.8149, 0.0000],
#          [1.8212, 0.0000],
#          [1.8261, 0.0000],
#          ...,
#          [1.8233, 0.0000],
#          [1.8162, 0.0000],
#          [1.8222, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# training iteration: 99 out of 100 iterations.ime=0.913
# input_data torch.Size([1, 89, 40, 40])
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# tensor([[[0.2306, 0.0000],
#          [0.0169, 0.0000],
#          [0.0053, 0.0000],
#          ...,
#          [1.8313, 0.0000],
#          [1.8231, 0.0000],
#          [1.8199, 0.0000]],
#
#         [[0.4545, 0.0000],
#          [1.8207, 0.0000],
#          [1.8276, 0.0000],
#          ...,
#          [1.8083, 0.0000],
#          [1.8218, 0.0000],
#          [1.8240, 0.0000]],
#
#         [[0.4513, 0.0000],
#          [1.8248, 0.0000],
#          [1.8180, 0.0000],
#          ...,
#          [1.8170, 0.0000],
#          [1.8236, 0.0000],
#          [1.8272, 0.0000]],
#
#         ...,
#
#         [[0.4517, 0.0000],
#          [1.8167, 0.0000],
#          [1.8292, 0.0000],
#          ...,
#          [1.8146, 0.0000],
#          [1.8097, 0.0000],
#          [1.8099, 0.0000]],
#
#         [[0.4558, 0.0000],
#          [1.8164, 0.0000],
#          [1.8272, 0.0000],
#          ...,
#          [1.8115, 0.0000],
#          [1.8191, 0.0000],
#          [1.8254, 0.0000]],
#
#         [[0.6508, 0.0000],
#          [1.8263, 0.0000],
#          [1.8256, 0.0000],
#          ...,
#          [1.8290, 0.0000],
#          [1.8057, 0.0000],
#          [1.8314, 0.0000]]], device='cuda:0')
# datashape torch.Size([89, 40, 40])
# x0shape torch.Size([40, 40, 2])
# datashape torch.Size([89, 40, 40])
# batch= 99 | loss=1.44320 | log loss=0.159 | time=0.896

# %%
print('network.grad.C', network.grad.C)
# %matplotlib inline
visualizer.visualize(network.grad.C.detach().cpu().numpy(),metadata)
# Out:
# network.grad.C Parameter containing:
# tensor([[0.1429, 0.1498, 0.1485, 0.0000, 0.0000, 0.1487, 0.0000, 0.0000, 0.0000,
#          0.0249, 0.0446, 0.1079, 0.0000, 0.0809, 0.0587, 0.0000, 0.0000, 0.0427,
#          0.0000, 0.0504, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.1429, 0.1498, 0.1486, 0.0000, 0.0000, 0.1487, 0.0000, 0.0000, 0.0000,
#          0.0249, 0.0446, 0.1079, 0.0000, 0.0809, 0.0587, 0.0000, 0.0000, 0.0427,
#          0.0000, 0.0503, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0031, 0.0000, 0.0043, 0.0062, 0.0176, 0.0178,
#          0.0049, 0.0000, 0.0068, 0.0199, 0.0054, 0.0000, 0.0000, 0.0062, 0.0140,
#          0.0031, 0.0000, 0.0000, 0.0065, 0.0331, 0.0031, 0.0419, 0.0209, 0.0351,
#          0.0178, 0.0000, 0.0002, 0.0298, 0.0161, 0.0000, 0.0303, 0.0000, 0.0000,
#          0.0411, 0.0022, 0.0322, 0.0045, 0.0000, 0.0356, 0.0257, 0.0409, 0.0000,
#          0.0238, 0.0291, 0.0034, 0.0303, 0.0075, 0.0147, 0.0328, 0.0158, 0.0240,
#          0.0000, 0.0208, 0.0236, 0.0165, 0.0222, 0.0003, 0.0352, 0.0295, 0.0227,
#          0.0253, 0.0000, 0.0239, 0.0000, 0.0000, 0.0324, 0.0023, 0.0379],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0031, 0.0000, 0.0043, 0.0062, 0.0176, 0.0178,
#          0.0049, 0.0000, 0.0068, 0.0199, 0.0054, 0.0000, 0.0000, 0.0062, 0.0140,
#          0.0031, 0.0000, 0.0000, 0.0065, 0.0331, 0.0031, 0.0419, 0.0209, 0.0351,
#          0.0178, 0.0000, 0.0002, 0.0298, 0.0161, 0.0000, 0.0303, 0.0000, 0.0000,
#          0.0411, 0.0022, 0.0322, 0.0045, 0.0000, 0.0356, 0.0257, 0.0409, 0.0000,
#          0.0238, 0.0291, 0.0034, 0.0303, 0.0075, 0.0147, 0.0328, 0.0158, 0.0240,
#          0.0000, 0.0208, 0.0236, 0.0165, 0.0222, 0.0003, 0.0352, 0.0295, 0.0227,
#          0.0253, 0.0000, 0.0239, 0.0000, 0.0000, 0.0324, 0.0023, 0.0379],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0031, 0.0000, 0.0043, 0.0062, 0.0176, 0.0178,
#          0.0049, 0.0000, 0.0068, 0.0199, 0.0054, 0.0000, 0.0000, 0.0062, 0.0140,
#          0.0031, 0.0000, 0.0000, 0.0065, 0.0331, 0.0031, 0.0419, 0.0209, 0.0351,
#          0.0178, 0.0000, 0.0002, 0.0298, 0.0161, 0.0000, 0.0303, 0.0000, 0.0000,
#          0.0411, 0.0022, 0.0322, 0.0045, 0.0000, 0.0356, 0.0257, 0.0409, 0.0000,
#          0.0238, 0.0291, 0.0034, 0.0303, 0.0075, 0.0147, 0.0328, 0.0158, 0.0240,
#          0.0000, 0.0208, 0.0236, 0.0165, 0.0222, 0.0003, 0.0352, 0.0295, 0.0227,
#          0.0253, 0.0000, 0.0239, 0.0000, 0.0000, 0.0324, 0.0023, 0.0379],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0031, 0.0000, 0.0043, 0.0062, 0.0176, 0.0178,
#          0.0049, 0.0000, 0.0068, 0.0199, 0.0054, 0.0000, 0.0000, 0.0062, 0.0140,
#          0.0031, 0.0000, 0.0000, 0.0065, 0.0331, 0.0031, 0.0419, 0.0209, 0.0351,
#          0.0178, 0.0000, 0.0002, 0.0298, 0.0161, 0.0000, 0.0303, 0.0000, 0.0000,
#          0.0411, 0.0022, 0.0322, 0.0045, 0.0000, 0.0356, 0.0257, 0.0409, 0.0000,
#          0.0238, 0.0291, 0.0034, 0.0303, 0.0075, 0.0147, 0.0328, 0.0158, 0.0240,
#          0.0000, 0.0208, 0.0236, 0.0165, 0.0222, 0.0003, 0.0352, 0.0295, 0.0226,
#          0.0253, 0.0000, 0.0239, 0.0000, 0.0000, 0.0324, 0.0023, 0.0379],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0031, 0.0000, 0.0043, 0.0062, 0.0176, 0.0178,
#          0.0049, 0.0000, 0.0068, 0.0199, 0.0054, 0.0000, 0.0000, 0.0062, 0.0140,
#          0.0031, 0.0000, 0.0000, 0.0065, 0.0331, 0.0031, 0.0419, 0.0209, 0.0351,
#          0.0178, 0.0000, 0.0002, 0.0298, 0.0161, 0.0000, 0.0303, 0.0000, 0.0000,
#          0.0411, 0.0022, 0.0322, 0.0045, 0.0000, 0.0356, 0.0257, 0.0409, 0.0000,
#          0.0238, 0.0291, 0.0034, 0.0303, 0.0075, 0.0147, 0.0328, 0.0158, 0.0240,
#          0.0000, 0.0208, 0.0236, 0.0165, 0.0222, 0.0003, 0.0352, 0.0295, 0.0227,
#          0.0253, 0.0000, 0.0239, 0.0000, 0.0000, 0.0324, 0.0023, 0.0379],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0031, 0.0000, 0.0043, 0.0062, 0.0176, 0.0178,
#          0.0049, 0.0000, 0.0068, 0.0199, 0.0054, 0.0000, 0.0000, 0.0062, 0.0140,
#          0.0031, 0.0000, 0.0000, 0.0065, 0.0331, 0.0031, 0.0419, 0.0209, 0.0351,
#          0.0178, 0.0000, 0.0002, 0.0298, 0.0161, 0.0000, 0.0303, 0.0000, 0.0000,
#          0.0411, 0.0022, 0.0322, 0.0045, 0.0000, 0.0356, 0.0257, 0.0409, 0.0000,
#          0.0238, 0.0291, 0.0034, 0.0303, 0.0075, 0.0147, 0.0328, 0.0158, 0.0240,
#          0.0000, 0.0208, 0.0236, 0.0165, 0.0222, 0.0003, 0.0352, 0.0295, 0.0227,
#          0.0253, 0.0000, 0.0239, 0.0000, 0.0000, 0.0324, 0.0023, 0.0379]],
#        device='cuda:0')
